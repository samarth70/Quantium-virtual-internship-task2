# %%
# !pip install dataprep

# %%
# !pip install datacompy

# %% [markdown]
# LOADING MODULES

# %%
import numpy as np
import pandas as pd
import datacompy
# import tensorflow as tf
# from tensorflow.keras import layers
from matplotlib import pyplot as plt
import seaborn as sns
from dataprep.eda import plot,plot_correlation,plot_missing
# %matplotlib inline

# %%
df1=pd.read_csv('/content/QVI_data.csv')

# %%
df1.head(50)
# Out:
#     LYLTY_CARD_NBR        DATE  ...               LIFESTAGE  PREMIUM_CUSTOMER
# 0             1000  2018-10-17  ...   YOUNG SINGLES/COUPLES           Premium
# 1             1002  2018-09-16  ...   YOUNG SINGLES/COUPLES        Mainstream
# 2             1003  2019-03-07  ...          YOUNG FAMILIES            Budget
# 3             1003  2019-03-08  ...          YOUNG FAMILIES            Budget
# 4             1004  2018-11-02  ...   OLDER SINGLES/COUPLES        Mainstream
# 5             1005  2018-12-28  ...  MIDAGE SINGLES/COUPLES        Mainstream
# 6             1007  2018-12-04  ...   YOUNG SINGLES/COUPLES            Budget
# 7             1007  2018-12-05  ...   YOUNG SINGLES/COUPLES            Budget
# 8             1009  2018-11-20  ...            NEW FAMILIES           Premium
# 9             1010  2018-09-09  ...   YOUNG SINGLES/COUPLES        Mainstream
# 10            1010  2018-12-14  ...   YOUNG SINGLES/COUPLES        Mainstream
# ...

# %% [markdown]
# DESCRIBING DATAFRAME

# %%
df1.describe()
# Out:
#        LYLTY_CARD_NBR      STORE_NBR  ...      TOT_SALES      PACK_SIZE
# count    2.648340e+05  264834.000000  ...  264834.000000  264834.000000
# mean     1.355488e+05     135.079423  ...       7.299346     182.425512
# std      8.057990e+04      76.784063  ...       2.527241      64.325148
# min      1.000000e+03       1.000000  ...       1.500000      70.000000
# 25%      7.002100e+04      70.000000  ...       5.400000     150.000000
# 50%      1.303570e+05     130.000000  ...       7.400000     170.000000
# 75%      2.030940e+05     203.000000  ...       9.200000     175.000000
# max      2.373711e+06     272.000000  ...      29.500000     380.000000
#
# [8 rows x 7 columns]

# %%
df1.aggregate
# Out:
# <bound method DataFrame.aggregate of         LYLTY_CARD_NBR        DATE  ...              LIFESTAGE  PREMIUM_CUSTOMER
# 0                 1000  2018-10-17  ...  YOUNG SINGLES/COUPLES           Premium
# 1                 1002  2018-09-16  ...  YOUNG SINGLES/COUPLES        Mainstream
# 2                 1003  2019-03-07  ...         YOUNG FAMILIES            Budget
# 3                 1003  2019-03-08  ...         YOUNG FAMILIES            Budget
# 4                 1004  2018-11-02  ...  OLDER SINGLES/COUPLES        Mainstream
# ...                ...         ...  ...                    ...               ...
# 264829         2370701  2018-12-08  ...         YOUNG FAMILIES        Mainstream
# 264830         2370751  2018-10-01  ...         YOUNG FAMILIES           Premium
# 264831         2370961  2018-10-24  ...         OLDER FAMILIES            Budget
# 264832         2370961  2018-10-27  ...         OLDER FAMILIES            Budget
# ...

# %% [markdown]
# SEPARATING TRIAL STORES -77,86,88

# %%
df1[df1.STORE_NBR == 77 ].describe()
df77=df1[df1.STORE_NBR == 77 ]
# df77.head()
# Out:
#        LYLTY_CARD_NBR        DATE  ...               LIFESTAGE  PREMIUM_CUSTOMER
# 73365           77000  2019-03-28  ...  MIDAGE SINGLES/COUPLES            Budget
# 73366           77000  2019-04-13  ...  MIDAGE SINGLES/COUPLES            Budget
# 73367           77000  2018-09-26  ...  MIDAGE SINGLES/COUPLES            Budget
# 73368           77001  2019-02-27  ...          YOUNG FAMILIES        Mainstream
# 73369           77001  2019-01-21  ...          YOUNG FAMILIES        Mainstream
#
# [5 rows x 12 columns]

# %%
df1[df1.STORE_NBR == 86 ].describe()
df77=df77.append(df1[df1.STORE_NBR == 86 ])

# %%
df77=df77.append(df1[df1.STORE_NBR == 88 ])

# %%
df77.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3974 entries, 73365 to 264833
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   LYLTY_CARD_NBR    3974 non-null   int64
#  1   DATE              3974 non-null   object
#  2   STORE_NBR         3974 non-null   int64
#  3   TXN_ID            3974 non-null   int64
#  4   PROD_NBR          3974 non-null   int64
#  5   PROD_NAME         3974 non-null   object
#  6   PROD_QTY          3974 non-null   int64
#  7   TOT_SALES         3974 non-null   float64
#  8   PACK_SIZE         3974 non-null   int64
#  9   BRAND             3974 non-null   object
#  10  LIFESTAGE         3974 non-null   object
#  11  PREMIUM_CUSTOMER  3974 non-null   object
# dtypes: float64(1), int64(6), object(5)
# memory usage: 403.6+ KB

# %%
df1 = df1[df1.STORE_NBR != 77]
df1 = df1[df1.STORE_NBR != 86]
df1 = df1[df1.STORE_NBR != 88]

# %% [markdown]
# CORRELATION BETWEEN TRIAL & CONTROL STORE

# %%
plot_correlation(df1)
# Out:
#   <div class="bk-root" id="51ba57d5-7c2a-4d0f-84c1-3d139bc46b95" data-root-id="2872"></div>
# <script>(function(root) {
#   function embed_document(root) {
#
# ...

# %%
plot_correlation(df77)
# Out:
#   <div class="bk-root" id="fe135b7a-900c-4592-8289-55560d5cb0d0" data-root-id="3086"></div>
# <script>(function(root) {
#   function embed_document(root) {
#
# ...

# %%
plot(df1)
# Out:
#   <div class="bk-root" id="657889a0-0ea6-463d-aa9d-a42c3957be0d" data-root-id="4528"></div>
# <script>(function(root) {
#   function embed_document(root) {
#
# ...

# %%
plot(df77)
# Out:
#   <div class="bk-root" id="ababe49f-0cd7-4465-95db-96097fef2f31" data-root-id="3645"></div>
# <script>(function(root) {
#   function embed_document(root) {
#
# ...

# %%
compare = datacompy.Compare(df1,df77,join_columns='BRAND')
print(compare.report())

# %%
df1.describe()
# Out:
#        lylty_card_nbr      store_nbr  ...      tot_sales      pack_size
# count   260860.000000  260860.000000  ...  260860.000000  260860.000000
# mean    136028.012788     135.832174  ...       7.295509     182.456433
# std      77295.238582      77.120990  ...       2.528377      64.326507
# min       1000.000000       1.000000  ...       1.500000      70.000000
# 25%      69119.000000      69.000000  ...       5.400000     150.000000
# 50%     133167.000000     133.000000  ...       7.400000     170.000000
# 75%     203330.000000     203.000000  ...       9.200000     175.000000
# max     883791.000000     272.000000  ...      29.500000     380.000000
#
# [8 rows x 7 columns]

# %%
df77.describe()
# Out:
#        lylty_card_nbr    store_nbr  ...    tot_sales    pack_size
# count    3.974000e+03  3974.000000  ...  3974.000000  3974.000000
# mean     1.040920e+05    85.667589  ...     7.551233   180.395823
# std      1.988414e+05     3.640526  ...     2.438625    64.211425
# min      7.700000e+04    77.000000  ...     1.500000    70.000000
# 25%      8.607500e+04    86.000000  ...     6.000000   150.000000
# 50%      8.624000e+04    86.000000  ...     7.600000   170.000000
# 75%      8.819200e+04    88.000000  ...     9.200000   175.000000
# max      2.373711e+06    88.000000  ...    25.500000   380.000000
#
# [8 rows x 7 columns]
